# %%
using TSSOS
using LinearAlgebra
using QuantumOptics
using DynamicPolynomials
using QuadGK
using JuMP
using Random
using NLopt

# %% [markdown]
# ## Define the quantum system

# %%
# We look at a typical Hamiltonian

#Drift Hamiltonian

H0 = [
    0 0 0;
    0 0.515916 0;
    0 0 1
];

H0 ./= norm(H0, Inf)

# Control Hamiltonian
V = [
    0 0.707107 0;
    0.707107 0 1;
    0 1 0
]

V ./= norm(V, Inf);

# %%
H0*V-V*H0
# Out:
# 3×3 Matrix{Float64}:
#  0.0       -0.364808   0.0
#  0.364808   0.0       -0.484084
#  0.0        0.484084   0.0

# %% [markdown]
# ## Useful functions with polynomials

# %%
function ∫(p::AbstractPolynomial, x::PolyVar, x_lower, x_upper)
    
    # get the index of the variable of integration
    ind_x = indexin([x], variables(p))[1]
        
    if isnothing(ind_x)
        # integration valuable is not found among vars
        return p * (x_upper - x_lower)
    end
    
    # get the indefinite integral
    int_p = sum(
        term * x * 1 // (exponents(term)[ind_x] + 1) for term in terms(p)
        init = 0 * x
    )
            
    # get the definite integral
    subs(int_p, x=>x_upper) - subs(int_p, x=>x_lower)
end

function ∫(M::AbstractMatrix, x::PolyVar, x_lower, x_upper)
   map(z -> ∫(z, x, x_lower, x_upper), M) 
end

function real_poly(p::Polynomial)
    #=
    Real part of the polynomial
    =#
    sum(
        real(c) * m for (c, m) in zip(coefficients(p), monomials(p))# if ~isapproxzero(abs(c))
    )
end

function square_frobenius_norm(M::AbstractArray)
    #=
    Square of the Frobenius norm of a matrix
    =#
    real_poly(sum(z' * z for z in M))
end

function square_frobenius_norm2(M::AbstractArray)
    #=
    Square of the Frobenius norm of a matrix
    =#
    sum(z' * z for z in M)
end
# Out:
# square_frobenius_norm2 (generic function with 1 method)

# %% [markdown]
# ## Magnus expansion

# %%
@polyvar x[1:3]
@polyvar t[1:3]

# final time
const T = 0.5

function u(t, x)
    # the polynomial shape for control
    sum(x[n] * t^(n - 1) for n = 1:length(x))
end

function A(t, x,)
    #=
    The generator of motion entering the Magnus expansion
    =#
    (H0 + V * u(t, x)) / im
end

function commutator(a, b)
    a * b - b * a
end 

# get the partial sum of the Magnus expansion
A₁ = A(t[1], x)
A₂ = A(t[2], x)

Ω = ∫(A₁, t[1], 0, T);

# 2nd term in the Magnus expansion
Ω .+= 1//2 * ∫(∫(
    commutator(A₁, A₂), 
    t[2], 0, t[1]), 
    t[1], 0, T
);

# 3nd term in the Magnus expansion

A₃ = A(t[3], x)

Ω .+= 1//6 * ∫(∫(∫(
    commutator(A₁, commutator(A₂, A₃)) + commutator(commutator(A₁, A₂), A₃),
    t[3], 0, t[2]),
    t[2], 0, t[1]),
    t[1], 0, T
);

# %% [markdown]
# ## Get random unitary target and take logarithm

# %%
function get_unitary(x::AbstractArray)
    #=
    Get the unitary given the coefficients for the polynomial control
    =#
    basis = NLevelBasis(size(H0)[1])

    𝓗₀ = DenseOperator(basis, basis, H0)
    𝓥 = DenseOperator(basis, basis, V)

    H = LazySum([1., u(0, x)], [𝓗₀, 𝓥])
        
    function 𝓗(t, psi)
        H.factors[2] = u(t, x)
        return H
    end

    _, 𝓤 = timeevolution.schroedinger_dynamic([0, T], identityoperator(basis, basis), 𝓗)
    
    return Matrix(𝓤[2].data)
end
# Out:
# get_unitary (generic function with 1 method)

# %%
function logarithm_mat(U)
    F= eigen(U)
    X = F.vectors
    L = Diagonal(F.values)
    n= 0
    theta_values = [log(λ) for λ in F.values]
    K = Diagonal(theta_values + 2*pi*im*n*[1,1,1])
    X*K*inv(X)
end
# Out:
# logarithm_mat (generic function with 1 method)

# %% [markdown]
# ## Functions to compare

# %%
function Magnus(x)
    # get the partial sum of the Magnus expansion
    A₁ = A(t[1], x)
    A₂ = A(t[2], x)
    
    Ω = ∫(A₁, t[1], 0, T);
    
    # 2nd term in the Magnus expansion
    Ω .+= 1//2 * ∫(∫(
        commutator(A₁, A₂), 
        t[2], 0, t[1]), 
        t[1], 0, T
    );
    
    # 3nd term in the Magnus expansion
    
    A₃ = A(t[3], x)
    
    Ω .+= 1//6 * ∫(∫(∫(
        commutator(A₁, commutator(A₂, A₃)) + commutator(commutator(A₁, A₂), A₃),
        t[3], 0, t[2]),
        t[2], 0, t[1]),
        t[1], 0, T
    );
    Ω

end
# Out:
# Magnus (generic function with 1 method)

# %%
function local_minimize(obj::AbstractPolynomial, init_x::AbstractArray)
    #=
    Perform local minimization of obj polynomial using init_x as initial guess
    =#
    vars = variables(obj)

    @assert length(vars) == length(init_x)
    
    function g(a...)
        # Converting polynomial expression to function to be minimize
        obj(vars => a)
    end
    
    model = Model(NLopt.Optimizer)

    set_optimizer_attribute(model, "algorithm", :LD_MMA)

    set_silent(model)
    @variable(model, y[1:length(vars)])

    # set initial guess
    for (var, init_val) in zip(y, init_x)
        set_start_value(var, init_val)
    end

    register(model, :g, length(y), g; autodiff = true)
    @NLobjective(model, Min, g(y...))
    JuMP.optimize!(model)

    map(value, y)
end
# Out:
# local_minimize (generic function with 1 method)

# %% [markdown]
# ## TSSOS

# %%
@time begin
    
n_samples = 1000
Random.seed!(6292022)

# randomly generate the coefficients for the polynomial control 
exact_x = -1 .+ 2 * rand(length(x) * n_samples)
exact_x = reshape(exact_x, (length(x), n_samples))

# The values of objective functions for exact x
obj_exact_x = zeros(n_samples)
    
# The array of target unitaries synthesized by the control x
U_targets = zeros(ComplexF64, n_samples, size(H0)...)

# the polynomial objective at min_x
glob_obj_min_x = zeros(n_samples)

# The global minimum via TSSOS library
tssos_glob_obj_min = zeros(n_samples)

# Frobenius norm difference between target and obtained unitaries
norm_U_target_minus_obtained = zeros(n_samples)

# Frobenius norm difference between target and the truncated Magnus expansion
norm_U_target_minus_expΩ_exact_x = zeros(n_samples)
norm_U_target_minus_expΩ_min_x = zeros(n_samples)

# The normalised overlap of the evolution and the target 
f_PSU = zeros(n_samples) 

# Convergence test for the Magnus expansion for the exact control (convergence_test_exact_x < 1)
convergence_test_exact_x = zeros(n_samples)


# Convergence test for the Magnus expansion for the obtained control (convergence_test_min_x < 1)
convergence_test_min_x = zeros(n_samples)

norm_diff_x = zeros(n_samples)

Threads.@threads for i=1:n_samples
    
    # target unitray
    U_targets[i, :, :] = U_target = get_unitary(exact_x[:, i])
        
    # get the polynomial objective function
    obj = square_frobenius_norm(
        Ω - logarithm_mat(U_targets[i,:,:])
    )
    
    # save the value of objective function for exact x
    obj_exact_x[i] = obj(exact_x[:, i])
  
    
    # Get the global minimum via TSSOS library
    opt,sol,data = tssos_first(obj, variables(obj); QUIET = true, solution = true)
    
    previous_sol = sol
    previous_opt = opt
    
    while ~isnothing(sol)
        previous_sol = sol
        previous_opt = opt
            
        opt,sol,data = tssos_higher!(data; QUIET = true, solution = true)
    end
    tssos_glob_obj_min[i] = previous_opt
    min_x = previous_sol
    
    # refine the estimate by local minimization
    #min_x = local_minimize(obj, min_x)
    
    # the polynomial objective at min_x
    glob_obj_min_x[i] = tssos_glob_obj_min[i]
        
    # get the Frobenius norm difference between target and obtained unitaries
    U_star = get_unitary(min_x)
    norm_U_target_minus_obtained[i] = norm(U_target - U_star)

    # The normalised overlap of the evolution and the target 
    f_PSU[i] = abs(tr(U_target' * U_star)) / size(U_star)[1]
        
    # check the accuracy of the Magnus expansion
    Ω_exact_x = convert(Matrix{ComplexF64}, subs(Ω, x=>exact_x[:, i]))
    norm_U_target_minus_expΩ_exact_x[i] = norm(U_target - exp(Ω_exact_x))

    Ω_min_x = convert(Matrix{ComplexF64}, subs(Ω, x=>min_x))
    norm_U_target_minus_expΩ_min_x[i] = norm(U_target - exp(Ω_min_x))
    
    # Convergence test for the Magnus expansion for the exact control
    convergence_test_exact_x[i] = quadgk(t -> opnorm(A(t, exact_x[:, i])), 0, T)[1] / π

    # Convergence test for the Magnus expansion for the obtained control
    convergence_test_min_x[i] = quadgk(t -> opnorm(A(t, min_x)), 0, T)[1] / π    
    
    norm_diff_x[i] = norm(exact_x[:, i] - min_x)
end

end
# Out:
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# optimum = 4.292325997349481e-8
# *********************************** TSSOS ***********************************Global optimality certified with relative optimality gap 0.000004%!
#
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# TSSOS is launching...
# optimum = 2.180934493982041e-8
# optimum = 4.856998206690139e-9Global optimality certified with relative optimality gap 0.000002%!
#
# Global optimality certified with relative optimality gap 0.000000%!
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# optimum = 1.1375725667020702e-8
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000001%!
#
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# optimum = 2.274802075734037e-8
# *********************************** TSSOS ***********************************Global optimality certified with relative optimality gap 0.000002%!
#
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# optimum = 1.3294727682041725e-8
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000001%!
#
# TSSOS is launching...
# No higher TS step of the TSSOS hierarchy!
# TSSOS is launching...
# TSSOS is launching...
# TSSOS is launching...
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# optimum = 3.0061470402266175e-8
# No higher TS step of the TSSOS hierarchy!Global optimality certified with relative optimality gap 0.000002%!
#
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# optimum = 4.125497533487001e-9
# optimum = 2.3003069892808464e-8Global optimality certified with relative optimality gap 0.000000%!
#
# Global optimality certified with relative optimality gap 0.000002%!
# TSSOS is launching...
# TSSOS is launching...
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# No higher TS step of the TSSOS hierarchy!
# optimum = 2.8041003682778737e-8
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000002%!
#
# *********************************** TSSOS ***********************************
# optimum = 3.444328422328204e-9
# optimum = 3.4200781623275155e-8Global optimality certified with relative optimality gap 0.000000%!
#
# *********************************** TSSOS ***********************************Global optimality certified with relative optimality gap 0.000003%!
#
# No higher TS step of the TSSOS hierarchy!
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# optimum = 1.835070097390441e-8
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000001%!
#
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# TSSOS is launching...
# TSSOS is launching...
# TSSOS is launching...
# optimum = 2.8648789151104873e-9
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000000%!
#
# optimum = 1.0459844934776687e-8
# optimum = 1.2884242309381931e-8Global optimality certified with relative optimality gap 0.000001%!
#
# optimum = 2.5559958719358825e-9Global optimality certified with relative optimality gap 0.000001%!
#
# No higher TS step of the TSSOS hierarchy!Global optimality certified with relative optimality gap 0.000000%!
#
# TSSOS is launching...
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# TSSOS is launching...
# optimum = 2.110183735394767e-8
# Global optimality certified with relative optimality gap 0.000002%!
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# optimum = 1.2272023203364183e-8
# optimum = 8.446544294566978e-9Global optimality certified with relative optimality gap 0.000001%!
#
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000001%!
#
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# optimum = 3.9395525206178674e-8
# No higher TS step of the TSSOS hierarchy!Global optimality certified with relative optimality gap 0.000004%!
#
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# optimum = 8.938761227025595e-9
# *********************************** TSSOS ***********************************Global optimality certified with relative optimality gap 0.000001%!
#
# optimum = 1.6111045756942052e-8
# *********************************** TSSOS ***********************************Global optimality certified with relative optimality gap 0.000002%!
#
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# No higher TS step of the TSSOS hierarchy!
# optimum = 3.7365646316928877e-8
# No higher TS step of the TSSOS hierarchy!Global optimality certified with relative optimality gap 0.000004%!
#
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# optimum = 1.6894724381253958e-8
# No higher TS step of the TSSOS hierarchy!Global optimality certified with relative optimality gap 0.000002%!
#
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# optimum = 2.3216471589131716e-8
# optimum = 2.2552634967414818e-8Global optimality certified with relative optimality gap 0.000002%!
#
# Global optimality certified with relative optimality gap 0.000002%!
# optimum = 1.1677738310698059e-8
# optimum = 9.79478533305284e-9Global optimality certified with relative optimality gap 0.000001%!
#
# optimum = 4.0232734735188005e-8Global optimality certified with relative optimality gap 0.000001%!
#
# No higher TS step of the TSSOS hierarchy!Global optimality certified with relative optimality gap 0.000004%!
#
# *********************************** TSSOS ***********************************
# optimum = 3.067205331285147e-8
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000002%!
#
# No higher TS step of the TSSOS hierarchy!
# optimum = 1.0137822736221757e-8
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000001%!
#
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# optimum = 4.482089575063479e-8
# *********************************** TSSOS ***********************************Global optimality certified with relative optimality gap 0.000004%!
#
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# TSSOS is launching...
# TSSOS is launching...
# optimum = 1.2624344772007538e-8
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000001%!
#
# TSSOS is launching...
# No higher TS step of the TSSOS hierarchy!
# TSSOS is launching...
# TSSOS is launching...
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# optimum = 1.3463625438583246e-8
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000001%!
#
# *********************************** TSSOS ***********************************
# optimum = 1.768040466536687e-8
# *********************************** TSSOS ***********************************Global optimality certified with relative optimality gap 0.000001%!
#
# optimum = 2.4723435985374404e-8
# optimum = 5.710776534890893e-9Global optimality certified with relative optimality gap 0.000002%!
#
# *********************************** TSSOS ***********************************Global optimality certified with relative optimality gap 0.000001%!
#
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# optimum = 1.858221172007605e-8
# *********************************** TSSOS ***********************************Global optimality certified with relative optimality gap 0.000002%!
#
# *********************************** TSSOS ***********************************
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# optimum = 1.2278895046477312e-8
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000001%!
#
# optimum = 1.6137637123742784e-8
# Global optimality certified with relative optimality gap 0.000001%!
# No higher TS step of the TSSOS hierarchy!
# TSSOS is launching...
# optimum = 2.390727778179158e-8
# No higher TS step of the TSSOS hierarchy!Global optimality certified with relative optimality gap 0.000002%!
#
# TSSOS is launching...
# optimum = 3.392214170105152e-8
# Global optimality certified with relative optimality gap 0.000003%!
# optimum = 1.14494803324987e-8
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000001%!
#
# optimum = 2.1416628261962918e-8
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000002%!
#
# optimum = 9.313097769371411e-9
# No higher TS step of the TSSOS hierarchy!Global optimality certified with relative optimality gap 0.000001%!
#
# optimum = 7.157958470606595e-9
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000001%!
#
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# optimum = 1.8860460562405832e-8
# *********************************** TSSOS ***********************************Global optimality certified with relative optimality gap 0.000002%!
#
# optimum = 1.1833621704494142e-8
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000001%!
#
# optimum = 1.34444552405061e-8
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000001%!
#
# *********************************** TSSOS ***********************************
# No higher TS step of the TSSOS hierarchy!
# TSSOS is launching...
# TSSOS is launching...
# TSSOS is launching...
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# optimum = 3.6685780783690054e-8
# No higher TS step of the TSSOS hierarchy!Global optimality certified with relative optimality gap 0.000004%!
#
# optimum = 1.2454837533328641e-8
# Global optimality certified with relative optimality gap 0.000001%!
# TSSOS is launching...
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# No higher TS step of the TSSOS hierarchy!
# TSSOS is launching...
# optimum = 3.619652535848067e-8
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000003%!
#
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# No higher TS step of the TSSOS hierarchy!
# optimum = 4.8552083974964555e-8
# optimum = 6.288873998117419e-8Global optimality certified with relative optimality gap 0.000004%!
#
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000006%!
#
# TSSOS is launching...
# No higher TS step of the TSSOS hierarchy!
# optimum = 2.016504439684763e-8
# *********************************** TSSOS ***********************************Global optimality certified with relative optimality gap 0.000002%!
#
# optimum = 2.3989728044089734e-8
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000002%!
#
# TSSOS is launching...
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# optimum = 5.308366359536647e-9
# Global optimality certified with relative optimality gap 0.000001%!
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# optimum = 1.1916631673664482e-8
# *********************************** TSSOS ***********************************Global optimality certified with relative optimality gap 0.000001%!
#
# TSSOS is launching...
# optimum = 1.6643782109778762e-8
# No higher TS step of the TSSOS hierarchy!Global optimality certified with relative optimality gap 0.000001%!
#
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# optimum = 1.3513562684640534e-8
# *********************************** TSSOS ***********************************Global optimality certified with relative optimality gap 0.000001%!
#
# optimum = 8.151817100957889e-9
# No higher TS step of the TSSOS hierarchy!Global optimality certified with relative optimality gap 0.000001%!
#
# TSSOS is launching...
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# optimum = 7.651689238456068e-9
# *********************************** TSSOS ***********************************Global optimality certified with relative optimality gap 0.000001%!
#
# optimum = 2.6838674805929884e-8
# No higher TS step of the TSSOS hierarchy!Global optimality certified with relative optimality gap 0.000002%!
#
# *********************************** TSSOS ***********************************
# optimum = 1.4478471005473931e-8
# *********************************** TSSOS ***********************************Global optimality certified with relative optimality gap 0.000001%!
#
# No higher TS step of the TSSOS hierarchy!
# optimum = 1.4457035574617165e-8
# *********************************** TSSOS ***********************************Global optimality certified with relative optimality gap 0.000001%!
#
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# TSSOS is launching...
# TSSOS is launching...
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# optimum = 3.143919961140485e-8
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000002%!
#
# No higher TS step of the TSSOS hierarchy!
# optimum = 4.916817902793768e-9
# optimum = 3.2768252596914258e-9Global optimality certified with relative optimality gap 0.000000%!
#
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000000%!
#
# optimum = 1.7520182018200074e-8
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000002%!
#
# No higher TS step of the TSSOS hierarchy!
# optimum = 2.1153558969964126e-8
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000002%!
#
# *********************************** TSSOS ***********************************
# optimum = 2.2110213781462832e-8
# No higher TS step of the TSSOS hierarchy!Global optimality certified with relative optimality gap 0.000002%!
#
# No higher TS step of the TSSOS hierarchy!
# optimum = 1.441696256624155e-8
# *********************************** TSSOS ***********************************Global optimality certified with relative optimality gap 0.000001%!
#
# optimum = 4.047415425072671e-9
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000000%!
#
# No higher TS step of the TSSOS hierarchy!
# TSSOS is launching...
# optimum = 3.364744227605431e-8
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000003%!
#
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# TSSOS is launching...
# No higher TS step of the TSSOS hierarchy!
# TSSOS is launching...
# optimum = 4.1994770417552726e-8
# optimum = 7.1525318954467e-9Global optimality certified with relative optimality gap 0.000003%!
#
# optimum = 1.7678381872202257e-8Global optimality certified with relative optimality gap 0.000001%!
#
# Global optimality certified with relative optimality gap 0.000002%!
# optimum = 9.491614976004744e-9
# *********************************** TSSOS ***********************************Global optimality certified with relative optimality gap 0.000001%!
#
# TSSOS is launching...
# No higher TS step of the TSSOS hierarchy!
# TSSOS is launching...
# optimum = 1.258256016283315e-8
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000001%!
#
# optimum = 4.330947780320245e-9
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000000%!
#
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# optimum = -4.4372862745857336e-10
# Global optimality certified with relative optimality gap 0.000000%!
# *********************************** TSSOS ***********************************
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# No higher TS step of the TSSOS hierarchy!
# TSSOS is launching...
# optimum = 7.391386287098983e-9
# No higher TS step of the TSSOS hierarchy!Global optimality certified with relative optimality gap 0.000001%!
#
# No higher TS step of the TSSOS hierarchy!
# TSSOS is launching...
# optimum = 1.1250010322600928e-8
# *********************************** TSSOS ***********************************Global optimality certified with relative optimality gap 0.000001%!
#
# No higher TS step of the TSSOS hierarchy!
# TSSOS is launching...
# optimum = 4.284862439404343e-8
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000004%!
#
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# No higher TS step of the TSSOS hierarchy!
# optimum = 9.26800983812241e-9
# Global optimality certified with relative optimality gap 0.000001%!
# No higher TS step of the TSSOS hierarchy!
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# optimum = 2.062990603407516e-8
# *********************************** TSSOS ***********************************Global optimality certified with relative optimality gap 0.000002%!
#
# *********************************** TSSOS ***********************************
# No higher TS step of the TSSOS hierarchy!
# optimum = 1.59727695153143e-8
# No higher TS step of the TSSOS hierarchy!Global optimality certified with relative optimality gap 0.000001%!
#
# TSSOS is launching...
# TSSOS is launching...
# No higher TS step of the TSSOS hierarchy!
# optimum = 1.976116438203766e-8
# Global optimality certified with relative optimality gap 0.000002%!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# No higher TS step of the TSSOS hierarchy!
# TSSOS is launching...
# optimum = 2.5588992413142738e-8
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000002%!
#
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# optimum = 1.2933175885472433e-8
# optimum = 1.3363693552393128e-8Global optimality certified with relative optimality gap 0.000001%!
#
# No higher TS step of the TSSOS hierarchy!Global optimality certified with relative optimality gap 0.000001%!
#
# TSSOS is launching...
# No higher TS step of the TSSOS hierarchy!
# TSSOS is launching...
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# TSSOS is launching...
# optimum = -4.309570810978217e-10
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000000%!
#
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# optimum = 9.947932706045012e-9
# optimum = 4.5315914495887484e-8Global optimality certified with relative optimality gap 0.000001%!
#
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000004%!
#
# optimum = 7.513557045834635e-9
# No higher TS step of the TSSOS hierarchy!Global optimality certified with relative optimality gap 0.000001%!
#
# *********************************** TSSOS ***********************************
# optimum = 2.1760279367931833e-8
# Global optimality certified with relative optimality gap 0.000002%!
# *********************************** TSSOS ***********************************
# No higher TS step of the TSSOS hierarchy!
# TSSOS is launching...
# optimum = 1.0625749126499775e-8
# No higher TS step of the TSSOS hierarchy!Global optimality certified with relative optimality gap 0.000001%!
#
# optimum = 3.172110573969056e-8
# optimum = 5.696455601350923e-8Global optimality certified with relative optimality gap 0.000003%!
#
# No higher TS step of the TSSOS hierarchy!Global optimality certified with relative optimality gap 0.000005%!
#
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# optimum = 3.613929479000107e-9
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000000%!
#
# *********************************** TSSOS ***********************************
# optimum = 1.2846336083321332e-8
# optimum = 1.8117192572997034e-8Global optimality certified with relative optimality gap 0.000001%!
#
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000001%!
#
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# optimum = 2.5833971594155495e-8
# No higher TS step of the TSSOS hierarchy!Global optimality certified with relative optimality gap 0.000002%!
#
# optimum = 2.184740763201716e-8
# *********************************** TSSOS ***********************************Global optimality certified with relative optimality gap 0.000002%!
#
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# optimum = 1.512091972852011e-8
# optimum = 5.935869888310325e-8Global optimality certified with relative optimality gap 0.000001%!
#
# optimum = 1.704197589439745e-8Global optimality certified with relative optimality gap 0.000005%!
#
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000001%!
#
# *********************************** TSSOS ***********************************
# optimum = 9.238280812420067e-9
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000001%!
#
# TSSOS is launching...
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# optimum = 7.050573256323997e-9
# No higher TS step of the TSSOS hierarchy!Global optimality certified with relative optimality gap 0.000001%!
#
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# TSSOS is launching...
# optimum = 1.910012557835633e-8
# No higher TS step of the TSSOS hierarchy!Global optimality certified with relative optimality gap 0.000002%!
#
# optimum = 1.7066823091771027e-8
# *********************************** TSSOS ***********************************Global optimality certified with relative optimality gap 0.000002%!
#
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# TSSOS is launching...
# No higher TS step of the TSSOS hierarchy!
# TSSOS is launching...
# No higher TS step of the TSSOS hierarchy!
# optimum = 5.850713602136207e-9
# Global optimality certified with relative optimality gap 0.000001%!
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# No higher TS step of the TSSOS hierarchy!
# TSSOS is launching...
# optimum = 1.1469290029257742e-8
# optimum = 5.915870576813344e-9Global optimality certified with relative optimality gap 0.000001%!
#
# optimum = 3.6793445002219495e-8Global optimality certified with relative optimality gap 0.000001%!
#
# optimum = 1.1073890142998167e-8Global optimality certified with relative optimality gap 0.000002%!
#
# optimum = 2.946230296718773e-8Global optimality certified with relative optimality gap 0.000001%!
#
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000002%!
#
# TSSOS is launching...
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# TSSOS is launching...
# No higher TS step of the TSSOS hierarchy!
# optimum = 1.7091165033467807e-8
# *********************************** TSSOS ***********************************Global optimality certified with relative optimality gap 0.000001%!
#
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# optimum = 8.88829163433028e-9
# Global optimality certified with relative optimality gap 0.000001%!
# TSSOS is launching...
# optimum = 4.2205930866856144e-8
# No higher TS step of the TSSOS hierarchy!Global optimality certified with relative optimality gap 0.000004%!
#
# optimum = 6.418629923357315e-9
# No higher TS step of the TSSOS hierarchy!Global optimality certified with relative optimality gap 0.000001%!
#
# optimum = 1.0166861614199806e-8
# *********************************** TSSOS ***********************************Global optimality certified with relative optimality gap 0.000001%!
#
# optimum = 8.743913726447877e-9
# optimum = 2.2816912959314643e-11Global optimality certified with relative optimality gap 0.000001%!
#
# optimum = 2.792944924172733e-8Global optimality certified with relative optimality gap 0.000000%!
#
# No higher TS step of the TSSOS hierarchy!Global optimality certified with relative optimality gap 0.000002%!
#
# No higher TS step of the TSSOS hierarchy!
# TSSOS is launching...
# optimum = 7.88208696103527e-9
# optimum = 1.9698366064104677e-8Global optimality certified with relative optimality gap 0.000001%!
#
# Global optimality certified with relative optimality gap 0.000002%!
# *********************************** TSSOS ***********************************
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# optimum = 9.320931973710173e-9
# optimum = 3.082524550777803e-8Global optimality certified with relative optimality gap 0.000001%!
#
# Global optimality certified with relative optimality gap 0.000003%!
# optimum = 2.2053381080782437e-8
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000002%!
#
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# optimum = 2.0584256697134853e-8
# optimum = 1.9763757532035846e-8Global optimality certified with relative optimality gap 0.000002%!
#
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000002%!
#
# optimum = 1.6632846673257443e-8
# No higher TS step of the TSSOS hierarchy!Global optimality certified with relative optimality gap 0.000001%!
#
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# optimum = 1.5390109904684156e-8
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000001%!
#
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# No higher TS step of the TSSOS hierarchy!
# optimum = 1.4709345623471217e-8
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000001%!
#
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# optimum = 6.057515967426784e-9
# *********************************** TSSOS ***********************************Global optimality certified with relative optimality gap 0.000001%!
#
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# optimum = 3.041780098094512e-8
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000002%!
#
# No higher TS step of the TSSOS hierarchy!
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# optimum = 2.2437519324524856e-8
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000002%!
#
# *********************************** TSSOS ***********************************
# optimum = 9.678458523976943e-9
# *********************************** TSSOS ***********************************Global optimality certified with relative optimality gap 0.000001%!
#
# TSSOS is launching...
# No higher TS step of the TSSOS hierarchy!
# TSSOS is launching...
# TSSOS is launching...
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# optimum = 2.483745350412e-8
# No higher TS step of the TSSOS hierarchy!Global optimality certified with relative optimality gap 0.000002%!
#
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# optimum = 7.412150154007453e-9
# optimum = 2.0263870881075182e-8Global optimality certified with relative optimality gap 0.000001%!
#
# No higher TS step of the TSSOS hierarchy!Global optimality certified with relative optimality gap 0.000002%!
#
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# optimum = 7.589638899678114e-9
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000001%!
#
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# optimum = 4.390968123845823e-9
# Global optimality certified with relative optimality gap 0.000000%!
# optimum = 9.788719010152045e-9
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000001%!
#
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# optimum = 4.1961538124307386e-8
# No higher TS step of the TSSOS hierarchy!Global optimality certified with relative optimality gap 0.000004%!
#
# TSSOS is launching...
# optimum = 1.585702656862871e-8
# *********************************** TSSOS ***********************************Global optimality certified with relative optimality gap 0.000001%!
#
# optimum = 2.8948287884569332e-8
# *********************************** TSSOS ***********************************Global optimality certified with relative optimality gap 0.000003%!
#
# TSSOS is launching...
# No higher TS step of the TSSOS hierarchy!
# optimum = 2.2057539021911416e-8
# No higher TS step of the TSSOS hierarchy!Global optimality certified with relative optimality gap 0.000002%!
#
# No higher TS step of the TSSOS hierarchy!
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# optimum = 1.4462455234589173e-8
# No higher TS step of the TSSOS hierarchy!Global optimality certified with relative optimality gap 0.000001%!
#
# No higher TS step of the TSSOS hierarchy!
# optimum = 3.042286515085888e-8
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000002%!
#
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# optimum = 5.324083423692307e-9
# *********************************** TSSOS ***********************************Global optimality certified with relative optimality gap 0.000000%!
#
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# optimum = 1.9828852784881835e-9
# optimum = 3.199476751402742e-8Global optimality certified with relative optimality gap 0.000000%!
#
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000003%!
#
# No higher TS step of the TSSOS hierarchy!
# optimum = 3.514447118845028e-8
# *********************************** TSSOS ***********************************Global optimality certified with relative optimality gap 0.000003%!
#
# optimum = 1.1406183115531962e-8
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000001%!
#
# optimum = 6.6855272383284635e-9
# *********************************** TSSOS ***********************************Global optimality certified with relative optimality gap 0.000001%!
#
# optimum = 3.774748858503636e-8
# optimum = 2.5368679748083307e-8Global optimality certified with relative optimality gap 0.000004%!
#
# *********************************** TSSOS ***********************************Global optimality certified with relative optimality gap 0.000002%!
#
# TSSOS is launching...
# optimum = 1.520724864597722e-8
# optimum = 3.499521142228376e-8Global optimality certified with relative optimality gap 0.000001%!
#
# optimum = 2.4218719294834017e-8Global optimality certified with relative optimality gap 0.000003%!
#
# No higher TS step of the TSSOS hierarchy!Global optimality certified with relative optimality gap 0.000002%!
#
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# No higher TS step of the TSSOS hierarchy!
# TSSOS is launching...
# No higher TS step of the TSSOS hierarchy!
# optimum = 1.5224846978337854e-8
# optimum = 6.757717413982716e-9Global optimality certified with relative optimality gap 0.000001%!
#
# No higher TS step of the TSSOS hierarchy!Global optimality certified with relative optimality gap 0.000001%!
#
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# optimum = 2.9438453949612766e-9
# optimum = 2.5160137759136857e-8Global optimality certified with relative optimality gap 0.000000%!
#
# No higher TS step of the TSSOS hierarchy!Global optimality certified with relative optimality gap 0.000002%!
#
# No higher TS step of the TSSOS hierarchy!
# optimum = 1.272821986425401e-8
# Global optimality certified with relative optimality gap 0.000001%!
# TSSOS is launching...
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# optimum = 1.4958466971486281e-9
# *********************************** TSSOS ***********************************Global optimality certified with relative optimality gap 0.000000%!
#
# No higher TS step of the TSSOS hierarchy!
# TSSOS is launching...
# TSSOS is launching...
# TSSOS is launching...
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# TSSOS is launching...
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# No higher TS step of the TSSOS hierarchy!
# optimum = 1.1650013999933766e-8
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000001%!
#
# TSSOS is launching...
# optimum = 1.7177793471904465e-8
# *********************************** TSSOS ***********************************Global optimality certified with relative optimality gap 0.000002%!
#
# *********************************** TSSOS ***********************************
# No higher TS step of the TSSOS hierarchy!
# TSSOS is launching...
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# optimum = 1.758175599413745e-8
# *********************************** TSSOS ***********************************Global optimality certified with relative optimality gap 0.000002%!
#
# No higher TS step of the TSSOS hierarchy!
# TSSOS is launching...
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# No higher TS step of the TSSOS hierarchy!
# TSSOS is launching...
# No higher TS step of the TSSOS hierarchy!
# optimum = 1.4185248788504455e-8
# optimum = 8.350143369412401e-9Global optimality certified with relative optimality gap 0.000001%!
#
# *********************************** TSSOS ***********************************Global optimality certified with relative optimality gap 0.000001%!
#
# No higher TS step of the TSSOS hierarchy!
# optimum = 3.1662559502380104e-8
# Global optimality certified with relative optimality gap 0.000003%!
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# TSSOS is launching...
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# optimum = 3.715739905310603e-8
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000004%!
#
# optimum = -3.424066279847362e-9
# optimum = 9.230500785863668e-9Global optimality certified with relative optimality gap 0.000000%!
#
# *********************************** TSSOS ***********************************Global optimality certified with relative optimality gap 0.000001%!
#
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# TSSOS is launching...
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# TSSOS is launching...
# TSSOS is launching...
# No higher TS step of the TSSOS hierarchy!
# optimum = 2.1723572984175346e-8
# Global optimality certified with relative optimality gap 0.000002%!
# optimum = 5.0147894127350444e-8
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000005%!
#
# TSSOS is launching...
# optimum = 1.535444649622384e-8
# optimum = 1.9001892980594825e-8Global optimality certified with relative optimality gap 0.000001%!
#
# Global optimality certified with relative optimality gap 0.000001%!
# optimum = 1.9735346322124865e-8
# *********************************** TSSOS ***********************************Global optimality certified with relative optimality gap 0.000002%!
#
# TSSOS is launching...
# TSSOS is launching...
# No higher TS step of the TSSOS hierarchy!
# optimum = 8.739732788374888e-9
# Global optimality certified with relative optimality gap 0.000001%!
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# TSSOS is launching...
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# ...
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# optimum = 3.5757815186597036e-8
# Global optimality certified with relative optimality gap 0.000003%!
# TSSOS is launching...
# optimum = 1.2055854109539371e-8
# Global optimality certified with relative optimality gap 0.000001%!
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# optimum = 3.4947090728920038e-9
# optimum = 1.0328311101831498e-8Global optimality certified with relative optimality gap 0.000000%!
#
# optimum = 4.8988439365899965e-9Global optimality certified with relative optimality gap 0.000001%!
#
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000000%!
#
# TSSOS is launching...
# optimum = 1.5975384770152762e-8
# Global optimality certified with relative optimality gap 0.000002%!
# optimum = 8.26133679733995e-9
# Global optimality certified with relative optimality gap 0.000001%!
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# optimum = 5.1283237674277735e-9
# Global optimality certified with relative optimality gap 0.000000%!
# optimum = 6.60270264603762e-9
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000001%!
#
# TSSOS is launching...
# optimum = 4.804419823499541e-9
# No higher TS step of the TSSOS hierarchy!Global optimality certified with relative optimality gap 0.000000%!
#
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# optimum = 6.0665960177077566e-9
# Global optimality certified with relative optimality gap 0.000001%!
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# optimum = 9.07177486713041e-9
# Global optimality certified with relative optimality gap 0.000001%!
# *********************************** TSSOS ***********************************
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# TSSOS is launching...
# optimum = 9.530001939734894e-9
# optimum = 9.416990121058023e-9Global optimality certified with relative optimality gap 0.000001%!
#
# Global optimality certified with relative optimality gap 0.000001%!
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# TSSOS is launching...
# optimum = 1.2122231932367692e-8
# Global optimality certified with relative optimality gap 0.000001%!
# No higher TS step of the TSSOS hierarchy!
# optimum = 1.0028473630813327e-8
# Global optimality certified with relative optimality gap 0.000001%!
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# optimum = 1.3067989504206442e-8
# Global optimality certified with relative optimality gap 0.000001%!
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# optimum = 2.7828515138211158e-8
# Global optimality certified with relative optimality gap 0.000002%!
# *********************************** TSSOS ***********************************
# No higher TS step of the TSSOS hierarchy!
# optimum = 1.6340383512049273e-8
# Global optimality certified with relative optimality gap 0.000001%!
# No higher TS step of the TSSOS hierarchy!
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# optimum = 2.3982672103310225e-8
# Global optimality certified with relative optimality gap 0.000002%!
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# optimum = 1.5746498750369588e-8
# optimum = 7.003943115167531e-9Global optimality certified with relative optimality gap 0.000001%!
#
# No higher TS step of the TSSOS hierarchy!Global optimality certified with relative optimality gap 0.000001%!
#
# optimum = 2.2356791560027032e-8
# Global optimality certified with relative optimality gap 0.000002%!
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# optimum = 2.070915058947854e-8
# Global optimality certified with relative optimality gap 0.000002%!
# *********************************** TSSOS ***********************************
# No higher TS step of the TSSOS hierarchy!
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# optimum = 2.20161322884567e-8
# Global optimality certified with relative optimality gap 0.000002%!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# optimum = 4.912334398679554e-8
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000005%!
#
# optimum = 1.4252135415531763e-8
# Global optimality certified with relative optimality gap 0.000001%!
# optimum = 1.5350182423086704e-8
# Global optimality certified with relative optimality gap 0.000001%!
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# optimum = 3.643150209914905e-8
# No higher TS step of the TSSOS hierarchy!Global optimality certified with relative optimality gap 0.000004%!
#
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# optimum = 9.046855994253406e-9
# Global optimality certified with relative optimality gap 0.000001%!
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# No higher TS step of the TSSOS hierarchy!
# TSSOS is launching...
# optimum = 1.7875699034298333e-9
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000000%!
#
# optimum = 2.771964335114421e-8
# No higher TS step of the TSSOS hierarchy!Global optimality certified with relative optimality gap 0.000002%!
#
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# No higher TS step of the TSSOS hierarchy!
# optimum = 7.623854844328734e-9
# Global optimality certified with relative optimality gap 0.000001%!
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# optimum = 4.808174749435676e-9
# Global optimality certified with relative optimality gap 0.000000%!
# TSSOS is launching...
# optimum = 1.3518938814508449e-8
# Global optimality certified with relative optimality gap 0.000001%!
# optimum = 1.672111649961834e-8
# Global optimality certified with relative optimality gap 0.000002%!
# *********************************** TSSOS ***********************************
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# optimum = 2.5603377467115667e-8
# Global optimality certified with relative optimality gap 0.000002%!
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# TSSOS is launching...
# optimum = 1.7644626431101948e-8
# No higher TS step of the TSSOS hierarchy!Global optimality certified with relative optimality gap 0.000002%!
#
# optimum = 1.328599004960899e-8
# No higher TS step of the TSSOS hierarchy!Global optimality certified with relative optimality gap 0.000001%!
#
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# optimum = 3.1719903302915957e-8
# *********************************** TSSOS ***********************************Global optimality certified with relative optimality gap 0.000002%!
#
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# optimum = 6.885291715740253e-9
# *********************************** TSSOS ***********************************Global optimality certified with relative optimality gap 0.000001%!
#
# TSSOS is launching...
# No higher TS step of the TSSOS hierarchy!
# TSSOS is launching...
# optimum = 9.41415876279951e-9
# Global optimality certified with relative optimality gap 0.000001%!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# optimum = 1.1048532672844096e-8
# No higher TS step of the TSSOS hierarchy!Global optimality certified with relative optimality gap 0.000001%!
#
# *********************************** TSSOS ***********************************
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# TSSOS is launching...
# TSSOS is launching...
# optimum = 2.8684601943112682e-8
# Global optimality certified with relative optimality gap 0.000003%!
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# optimum = 1.5245080981665308e-8
# Global optimality certified with relative optimality gap 0.000001%!
# optimum = 2.644733212231988e-9
# Global optimality certified with relative optimality gap 0.000000%!
# optimum = 2.2949133891917205e-8
# Global optimality certified with relative optimality gap 0.000002%!
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# optimum = 7.117452827631174e-9
# Global optimality certified with relative optimality gap 0.000001%!
# optimum = 1.5005208809546943e-8
# No higher TS step of the TSSOS hierarchy!Global optimality certified with relative optimality gap 0.000001%!
#
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# optimum = 9.638158245046457e-9
# Global optimality certified with relative optimality gap 0.000001%!
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# No higher TS step of the TSSOS hierarchy!
# TSSOS is launching...
# optimum = 1.8392199182095944e-8
# Global optimality certified with relative optimality gap 0.000002%!
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# optimum = 1.7021717786566502e-8
# Global optimality certified with relative optimality gap 0.000001%!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# optimum = 1.0167827515188993e-8
# No higher TS step of the TSSOS hierarchy!Global optimality certified with relative optimality gap 0.000001%!
#
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# optimum = 6.913185346063793e-9
# Global optimality certified with relative optimality gap 0.000001%!
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# optimum = 1.7122390058059676e-8
# Global optimality certified with relative optimality gap 0.000002%!
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# optimum = 2.208670609840286e-8
# Global optimality certified with relative optimality gap 0.000002%!
# optimum = 6.614047603537725e-8
# Global optimality certified with relative optimality gap 0.000006%!
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# optimum = 4.9713180482328866e-9
# Global optimality certified with relative optimality gap 0.000000%!
# optimum = 1.572937195058078e-8
# Global optimality certified with relative optimality gap 0.000001%!
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# optimum = 1.130658662383236e-8
# Global optimality certified with relative optimality gap 0.000001%!
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# optimum = 3.0430627742926957e-9
# Global optimality certified with relative optimality gap 0.000000%!
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# optimum = 3.041435921197004e-8
# Global optimality certified with relative optimality gap 0.000003%!
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# optimum = -1.6394844827519839e-9
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000000%!
#
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# optimum = 2.9590557062965956e-8
# *********************************** TSSOS ***********************************Global optimality certified with relative optimality gap 0.000003%!
#
# TSSOS is launching...
# No higher TS step of the TSSOS hierarchy!
# optimum = 9.573694847589741e-9
# Global optimality certified with relative optimality gap 0.000001%!
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# optimum = 1.4354102999608797e-8
# Global optimality certified with relative optimality gap 0.000001%!
# optimum = 9.547986242702507e-9
# No higher TS step of the TSSOS hierarchy!Global optimality certified with relative optimality gap 0.000001%!
#
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# optimum = 1.334091314637497e-8
# Global optimality certified with relative optimality gap 0.000001%!
# No higher TS step of the TSSOS hierarchy!
# 4112.028070 seconds (20.46 M allocations: 1.278 GiB, 0.00% gc time, 12.53% compilation time)

# %%
using HDF5


h5open("results.hdf5", "w") do fid
    fid["U_targets"] = U_targets
    fid["exact_x"] = exact_x
    fid["obj_exact_x"] = obj_exact_x
    fid["tssos_glob_obj_min"] = tssos_glob_obj_min
    fid["norm_U_target_minus_obtained"] = norm_U_target_minus_obtained
    fid["f_PSU"] = f_PSU
    fid["convergence_test_exact_x"] = convergence_test_exact_x
    fid["convergence_test_min_x"] = convergence_test_min_x
end;
