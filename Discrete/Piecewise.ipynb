# %%
using TSSOS
using LinearAlgebra
using QuantumOptics
using DynamicPolynomials
using QuadGK
using JuMP
using Random
using NLopt

# %% [markdown]
# ## Define the quantum system

# %%
# We look at a typical Hamiltonian

#Drift Hamiltonian

H0 = [
    0 0 0;
    0 0.515916 0;
    0 0 1
];

H0 ./= norm(H0, Inf)

# Control Hamiltonian
V = [
    0 0.707107 0;
    0.707107 0 1;
    0 1 0
]

V ./= norm(V, Inf);

# final time
const T = 0.5
m =2
dt = T/m
# Out:
# 0.25

# %%
H0*V-V*H0
# Out:
# 3×3 Matrix{Float64}:
#  0.0       -0.364808   0.0
#  0.364808   0.0       -0.484084
#  0.0        0.484084   0.0

# %% [markdown]
# ## Useful functions with polynomials

# %%
function ∫(p::AbstractPolynomial, x::PolyVar, x_lower, x_upper)
    
    # get the index of the variable of integration
    ind_x = indexin([x], variables(p))[1]
        
    if isnothing(ind_x)
        # integration valuable is not found among vars
        return p * (x_upper - x_lower)
    end
    
    # get the indefinite integral
    int_p = sum(
        term * x * 1 // (exponents(term)[ind_x] + 1) for term in terms(p)
        init = 0 * x
    )
            
    # get the definite integral
    subs(int_p, x=>x_upper) - subs(int_p, x=>x_lower)
end

function ∫(M::AbstractMatrix, x::PolyVar, x_lower, x_upper)
   map(z -> ∫(z, x, x_lower, x_upper), M) 
end

function real_poly(p::Polynomial)
    #=
    Real part of the polynomial
    =#
    sum(
        real(c) * m for (c, m) in zip(coefficients(p), monomials(p))# if ~isapproxzero(abs(c))
    )
end

function square_frobenius_norm(M::AbstractArray)
    #=
    Square of the Frobenius norm of a matrix
    =#
    real_poly(sum(z' * z for z in M))
end

function square_frobenius_norm2(M::AbstractArray)
    #=
    Square of the Frobenius norm of a matrix
    =#
    sum(z' * z for z in M)
end
# Out:
# square_frobenius_norm2 (generic function with 1 method)

# %% [markdown]
# ## Magnus expansion

# %%
@polyvar x[1:m]
@polyvar t[1:3]

function u(t, x)
    # the polynomial shape for control
    sum(x[n] * t^(n - 1) for n = 1:length(x))
end

function A(t, x,)
    #=
    The generator of motion entering the Magnus expansion
    =#
    (H0 + V * u(t, x)) / im
end

function commutator(a, b)
    a * b - b * a
end 

M = [-im * dt * (H0 + x[i] * V) for i in 1:m];

X = sum(M) ## first term

function commutator(A, B)
        return A * B - B * A
end

## second term
for i in 1:m
    for j in i:m
        X += 0.5 * commutator(M[i], M[j])
    end
end


## third term
for i in 1:m
    for j in i:m
        for k in j:m
        X += 1/6 * (commutator(M[i],commutator(M[j],M[k]))+commutator(M[k],commutator(M[j],M[i])))
        end
    end
end

## third term
for i in 1:m
    for j in i:m
        for k in j:m
            for l in k:m
                X += 1/12 *( commutator(commutator(commutator(M[i],M[j]),M[k]),M[l]) + commutator(M[i],commutator(commutator(M[j],M[k]),M[l])) + commutator(M[i],commutator(M[j],commutator(M[k],M[l]))) + commutator(M[j],commutator(M[k],commutator(M[l],M[i])))  )
            end
        
        end
    end
end

# %% [markdown]
# ## Get random unitary target and take logarithm

# %%
function get_unitary(x::AbstractArray)
    #=
    Get the unitary given the coefficients for the polynomial control
    =#
    prod(exp(-im *dt* (H0 + xx * V)) for xx in x)
end
# Out:
# get_unitary (generic function with 1 method)

# %%
function logarithm_mat(U)
    F= eigen(U)
    Z = F.vectors
    L = Diagonal(F.values)
    n= 0
    theta_values = [log(λ) for λ in F.values]
    K = Diagonal(theta_values + 2*pi*im*n*[1,1,1])
    Z*K*inv(Z)
end
# Out:
# logarithm_mat (generic function with 1 method)

# %% [markdown]
# ## Functions to compare

# %%
function local_minimize(obj::AbstractPolynomial, init_x::AbstractArray)
    #=
    Perform local minimization of obj polynomial using init_x as initial guess
    =#
    vars = variables(obj)

    @assert length(vars) == length(init_x)
    
    function g(a...)
        # Converting polynomial expression to function to be minimize
        obj(vars => a)
    end
    
    model = Model(NLopt.Optimizer)

    set_optimizer_attribute(model, "algorithm", :LD_MMA)

    set_silent(model)
    @variable(model, y[1:length(vars)])

    # set initial guess
    for (var, init_val) in zip(y, init_x)
        set_start_value(var, init_val)
    end

    register(model, :g, length(y), g; autodiff = true)
    @NLobjective(model, Min, g(y...))
    JuMP.optimize!(model)

    map(value, y)
end
# Out:
# local_minimize (generic function with 1 method)

# %% [markdown]
# ## TSSOS

# %%
@time begin
    
n_samples = 100
Random.seed!(6292022)

# randomly generate the coefficients for the polynomial control 
exact_x = -1 .+ 2 * rand(length(x) * n_samples)
exact_x = reshape(exact_x, (length(x), n_samples))

# The values of objective functions for exact x
obj_exact_x = zeros(n_samples)
    
# The array of target unitaries synthesized by the control x
U_targets = zeros(ComplexF64, n_samples, size(H0)...)

# the polynomial objective at min_x
glob_obj_min_x = zeros(n_samples)

# The global minimum via TSSOS library
tssos_glob_obj_min = zeros(n_samples)

# Frobenius norm difference between target and obtained unitaries
norm_U_target_minus_obtained = zeros(n_samples)

# Frobenius norm difference between target and the truncated Magnus expansion
norm_U_target_minus_expΩ_exact_x = zeros(n_samples)
norm_U_target_minus_expΩ_min_x = zeros(n_samples)

# The normalised overlap of the evolution and the target 
f_PSU = zeros(n_samples) 

# Convergence test for the Magnus expansion for the exact control (convergence_test_exact_x < 1)
convergence_test_exact_x = zeros(n_samples)


# Convergence test for the Magnus expansion for the obtained control (convergence_test_min_x < 1)
convergence_test_min_x = zeros(n_samples)

norm_diff_x = zeros(n_samples)

Threads.@threads for i=1:n_samples
    
    # target unitray
    U_targets[i, :, :] = U_target = get_unitary(exact_x[:, i])
        
    # get the polynomial objective function
    obj = square_frobenius_norm(
        X - logarithm_mat(U_targets[i,:,:])
    )
    
    # save the value of objective function for exact x
    obj_exact_x[i] = obj(exact_x[:, i])
  
    
    # Get the global minimum via TSSOS library
    opt,sol,data = tssos_first(obj, variables(obj); QUIET = true, solution = true)
    
    previous_sol = sol
    previous_opt = opt
    
    while ~isnothing(sol)
        previous_sol = sol
        previous_opt = opt
            
        opt,sol,data = tssos_higher!(data; QUIET = true, solution = true)
    end
    tssos_glob_obj_min[i] = previous_opt
    min_x = previous_sol
    
    # refine the estimate by local minimization
    #min_x = local_minimize(obj, min_x)
    
    # the polynomial objective at min_x
    glob_obj_min_x[i] = tssos_glob_obj_min[i]
        
    # get the Frobenius norm difference between target and obtained unitaries
    U_star = get_unitary(min_x)
    norm_U_target_minus_obtained[i] = norm(U_target - U_star)

    # The normalised overlap of the evolution and the target 
    f_PSU[i] = abs(tr(U_target' * U_star)) / size(U_star)[1]
        
end

end
# Out:
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# optimum = 4.839983649066241e-7
# Global optimality certified with relative optimality gap 0.000002%!
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# optimum = 2.5771750082806067e-7
# *********************************** TSSOS ***********************************Global optimality certified with relative optimality gap 0.000001%!
#
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# optimum = 1.3537035099362898e-8
# Global optimality certified with relative optimality gap 0.000001%!
# *********************************** TSSOS ***********************************
# optimum = 2.585121230236478e-7
# *********************************** TSSOS ***********************************Global optimality certified with relative optimality gap 0.000001%!
#
# optimum = 1.3760107897133577e-5
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000005%!
#
# *********************************** TSSOS ***********************************
# optimum = 1.1816287629940746e-5
# optimum = 5.0381178303934285e-8Global optimality certified with relative optimality gap 0.000002%!
#
# No higher TS step of the TSSOS hierarchy!Global optimality certified with relative optimality gap 0.000005%!
#
# No higher TS step of the TSSOS hierarchy!
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# optimum = 8.528583001458286e-7
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000002%!
#
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# optimum = 1.4683110320270877e-6
# Global optimality certified with relative optimality gap 0.000003%!
# No higher TS step of the TSSOS hierarchy!
# optimum = 4.925170432181618e-6
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000001%!
#
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# optimum = 1.2380485791419307e-6
# No higher TS step of the TSSOS hierarchy!Global optimality certified with relative optimality gap 0.000002%!
#
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# No higher TS step of the TSSOS hierarchy!
# optimum = 9.98952796915243e-9
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000001%!
#
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# optimum = 9.737336766162822e-7
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000002%!
#
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# optimum = 6.43353920313215e-9
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000001%!
#
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# TSSOS is launching...
# optimum = 2.291677613983643e-6
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000003%!
#
# TSSOS is launching...
# optimum = 3.1183236223108575e-8
# *********************************** TSSOS ***********************************Global optimality certified with relative optimality gap 0.000001%!
#
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# optimum = 1.9063509911932197e-6
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000002%!
#
# TSSOS is launching...
# TSSOS is launching...
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# optimum = 3.4321747575746006e-8
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000001%!
#
# optimum = 2.305573228695524e-6
# *********************************** TSSOS ***********************************Global optimality certified with relative optimality gap 0.000003%!
#
# optimum = 5.47250967600353e-6
# Global optimality certified with relative optimality gap 0.000004%!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# No higher TS step of the TSSOS hierarchy!
# optimum = 1.6699387538422141e-7
# *********************************** TSSOS ***********************************Global optimality certified with relative optimality gap 0.000001%!
#
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# TSSOS is launching...
# No higher TS step of the TSSOS hierarchy!
# optimum = 3.6997852728855637e-7
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000001%!
#
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# optimum = 1.259280189954897e-7
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000001%!
#
# TSSOS is launching...
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# optimum = 1.3011343629350944e-5
# optimum = 2.3951904003420727e-8Global optimality certified with relative optimality gap 0.000002%!
#
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000001%!
#
# No higher TS step of the TSSOS hierarchy!
# optimum = 1.206523890335764e-6
# No higher TS step of the TSSOS hierarchy!Global optimality certified with relative optimality gap 0.000002%!
#
# TSSOS is launching...
# No higher TS step of the TSSOS hierarchy!
# optimum = 3.1099579653915175e-8
# optimum = 1.2209329055621494e-5Global optimality certified with relative optimality gap 0.000003%!
#
# optimum = 1.069001151255726e-6
# Global optimality certified with relative optimality gap 0.000002%!
# No higher TS step of the TSSOS hierarchy!
# Global optimality certified with relative optimality gap 0.000002%!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# optimum = 1.6252749226371232e-8
# No higher TS step of the TSSOS hierarchy!Global optimality certified with relative optimality gap 0.000001%!
#
# TSSOS is launching...
# No higher TS step of the TSSOS hierarchy!
# optimum = 1.652844173180631e-5
# optimum = 7.433046039956082e-6Global optimality certified with relative optimality gap 0.000004%!
#
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000001%!
#
# TSSOS is launching...
# TSSOS is launching...
# TSSOS is launching...
# optimum = 3.410055960919109e-7
# optimum = 3.926769010265078e-6Global optimality certified with relative optimality gap 0.000002%!
#
# No higher TS step of the TSSOS hierarchy!Global optimality certified with relative optimality gap 0.000004%!
#
# optimum = 6.945184778342349e-8
# Global optimality certified with relative optimality gap 0.000003%!
# TSSOS is launching...
# No higher TS step of the TSSOS hierarchy!
# optimum = 2.0547507048682998e-7
# optimum = 4.916680074820632e-7Global optimality certified with relative optimality gap 0.000001%!
#
# Global optimality certified with relative optimality gap 0.000002%!
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# TSSOS is launching...
# optimum = 3.68757479687504e-6
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000001%!
#
# optimum = 2.1857019086219304e-6
# *********************************** TSSOS ***********************************Global optimality certified with relative optimality gap 0.000002%!
#
# optimum = 5.11527176817904e-7
# No higher TS step of the TSSOS hierarchy!Global optimality certified with relative optimality gap 0.000002%!
#
# TSSOS is launching...
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# optimum = 8.610851476031205e-9
# optimum = 3.9659280134575955e-6Global optimality certified with relative optimality gap 0.000001%!
#
# optimum = 6.015313621414896e-8Global optimality certified with relative optimality gap 0.000001%!
#
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000001%!
#
# TSSOS is launching...
# optimum = 2.8674188464112833e-7
# optimum = 6.098193210658218e-8Global optimality certified with relative optimality gap 0.000002%!
#
# *********************************** TSSOS ***********************************Global optimality certified with relative optimality gap 0.000003%!
#
# TSSOS is launching...
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# optimum = 6.473614589395815e-6
# *********************************** TSSOS ***********************************Global optimality certified with relative optimality gap 0.000001%!
#
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# optimum = 1.28683535883029e-6
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000003%!
#
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# TSSOS is launching...
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# optimum = 5.81162711535216e-7
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000002%!
#
# No higher TS step of the TSSOS hierarchy!
# optimum = 9.996460554891107e-9
# *********************************** TSSOS ***********************************Global optimality certified with relative optimality gap 0.000001%!
#
# TSSOS is launching...
# No higher TS step of the TSSOS hierarchy!
# optimum = 3.628456791978409e-5
# optimum = 3.546759660279776e-6Global optimality certified with relative optimality gap 0.000006%!
#
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000002%!
#
# No higher TS step of the TSSOS hierarchy!
# optimum = 1.5260155542328007e-5
# *********************************** TSSOS ***********************************Global optimality certified with relative optimality gap 0.000004%!
#
# TSSOS is launching...
# optimum = 2.7848028724856147e-5
# No higher TS step of the TSSOS hierarchy!Global optimality certified with relative optimality gap 0.000005%!
#
# optimum = 6.258540739766068e-8
# Global optimality certified with relative optimality gap 0.000001%!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# optimum = 4.698165639921721e-7
# *********************************** TSSOS ***********************************Global optimality certified with relative optimality gap 0.000002%!
#
# TSSOS is launching...
# optimum = 1.486278998771502e-5
# Global optimality certified with relative optimality gap 0.000003%!
# *********************************** TSSOS ***********************************
# optimum = 4.5241487451341646e-8
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000002%!
#
# optimum = 1.9750303787267377e-8
# optimum = 1.0053040991089169e-7Global optimality certified with relative optimality gap 0.000001%!
#
# No higher TS step of the TSSOS hierarchy!Global optimality certified with relative optimality gap 0.000001%!
#
# TSSOS is launching...
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# optimum = 1.0183245476967857e-8
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000001%!
#
# TSSOS is launching...
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# optimum = 2.4408078127564288e-6
# Global optimality certified with relative optimality gap 0.000003%!
# optimum = 1.4118169187918679e-7
# Global optimality certified with relative optimality gap 0.000001%!
# TSSOS is launching...
# optimum = 4.43395817760419e-7
# No higher TS step of the TSSOS hierarchy!Global optimality certified with relative optimality gap 0.000002%!
#
# TSSOS is launching...
# optimum = 2.3938470551661438e-6
# Global optimality certified with relative optimality gap 0.000003%!
# No higher TS step of the TSSOS hierarchy!
# TSSOS is launching...
# TSSOS is launching...
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# optimum = 3.406201218934558e-7
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000001%!
#
# optimum = 1.7924073706808078e-6
# *********************************** TSSOS ***********************************Global optimality certified with relative optimality gap 0.000002%!
#
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# TSSOS is launching...
# No higher TS step of the TSSOS hierarchy!
# optimum = 8.479784660346668e-6
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000002%!
#
# optimum = 6.370048370354901e-6
# No higher TS step of the TSSOS hierarchy!Global optimality certified with relative optimality gap 0.000001%!
#
# optimum = 2.7420986541267454e-8
# Global optimality certified with relative optimality gap 0.000003%!
# TSSOS is launching...
# No higher TS step of the TSSOS hierarchy!
# optimum = 1.9944891159871857e-6
# Global optimality certified with relative optimality gap 0.000002%!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# TSSOS is launching...
# optimum = 3.566091768311366e-6
# Global optimality certified with relative optimality gap 0.000003%!
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# optimum = 1.909730408578229e-8
# optimum = 5.70265694405874e-6Global optimality certified with relative optimality gap 0.000001%!
#
# optimum = 8.026077112681115e-6Global optimality certified with relative optimality gap 0.000001%!
#
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000002%!
#
# TSSOS is launching...
# TSSOS is launching...
# No higher TS step of the TSSOS hierarchy!
# optimum = 6.0226374530983795e-6
# Global optimality certified with relative optimality gap 0.000004%!
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# TSSOS is launching...
# No higher TS step of the TSSOS hierarchy!
# optimum = 4.759899155117068e-6
# optimum = 9.804735133095549e-7Global optimality certified with relative optimality gap 0.000001%!
#
# *********************************** TSSOS ***********************************Global optimality certified with relative optimality gap 0.000002%!
#
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# optimum = 1.561134634372723e-8
# Global optimality certified with relative optimality gap 0.000001%!
# No higher TS step of the TSSOS hierarchy!
# optimum = 2.087075895705948e-6
# optimum = 1.5889223201004723e-7
# Global optimality certified with relative optimality gap 0.000001%!
# No higher TS step of the TSSOS hierarchy!Global optimality certified with relative optimality gap 0.000002%!
#
# No higher TS step of the TSSOS hierarchy!
# optimum = 3.2483872320787405e-8
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000003%!
#
# TSSOS is launching...
# No higher TS step of the TSSOS hierarchy!
# optimum = 4.6374458910374006e-7
# optimum = 7.977003596973853e-8
# Global optimality certified with relative optimality gap 0.000001%!
# Global optimality certified with relative optimality gap 0.000001%!
# optimum = 3.4442715943177363e-6
# Global optimality certified with relative optimality gap 0.000002%!
# optimum = 2.8475901727347468e-8
# No higher TS step of the TSSOS hierarchy!Global optimality certified with relative optimality gap 0.000003%!
#
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# No higher TS step of the TSSOS hierarchy!
# TSSOS is launching...
# optimum = 3.38304483033499e-8
# No higher TS step of the TSSOS hierarchy!Global optimality certified with relative optimality gap 0.000003%!
#
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# optimum = 3.277603992114966e-6
# TSSOS is launching...Global optimality certified with relative optimality gap 0.000003%!
#
# optimum = 2.1562132866611494e-7
# optimum = 1.1164643483140057e-8Global optimality certified with relative optimality gap 0.000001%!
#
# No higher TS step of the TSSOS hierarchy!Global optimality certified with relative optimality gap 0.000001%!
#
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# *********************************** TSSOS ***********************************
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# optimum = 5.149811204042048e-7
# No higher TS step of the TSSOS hierarchy!Global optimality certified with relative optimality gap 0.000001%!
#
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# TSSOS is launching...
# optimum = 5.062480502811823e-7
# optimum = 3.535265722320225e-8
# Global optimality certified with relative optimality gap 0.000003%!
# Global optimality certified with relative optimality gap 0.000001%!
# optimum = 2.2375764797252633e-5
# Global optimality certified with relative optimality gap 0.000003%!
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# optimum = 2.9158843909342047e-6
# Global optimality certified with relative optimality gap 0.000003%!
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# TSSOS is launching...
# No higher TS step of the TSSOS hierarchy!
# optimum = 8.614438212794342e-8
# TSSOS is launching...
# Global optimality certified with relative optimality gap 0.000001%!
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
# optimum = 3.6384494259108155e-7
# Global optimality certified with relative optimality gap 0.000002%!
# optimum = 3.266922006375219e-8
# No higher TS step of the TSSOS hierarchy!Global optimality certified with relative optimality gap 0.000003%!
#
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# optimum = 1.10459597858794e-7
# optimum = 4.454622887262917e-6
# Global optimality certified with relative optimality gap 0.000001%!
# No higher TS step of the TSSOS hierarchy!Global optimality certified with relative optimality gap 0.000001%!
#
# No higher TS step of the TSSOS hierarchy!
# optimum = 1.4632732922512176e-5
# No higher TS step of the TSSOS hierarchy!
# Global optimality certified with relative optimality gap 0.000004%!
# No higher TS step of the TSSOS hierarchy!
# No higher TS step of the TSSOS hierarchy!
#  43.325820 seconds (2.26 M allocations: 126.431 MiB, 358.50% compilation time)

# %%
using HDF5

filename = "results_$(m).hdf5"
h5open(filename, "w") do fid
    fid["U_targets"] = U_targets
    fid["exact_x"] = exact_x
    fid["obj_exact_x"] = obj_exact_x
    fid["tssos_glob_obj_min"] = tssos_glob_obj_min
    fid["norm_U_target_minus_obtained"] = norm_U_target_minus_obtained
    fid["f_PSU"] = f_PSU
    fid["convergence_test_exact_x"] = convergence_test_exact_x
    fid["convergence_test_min_x"] = convergence_test_min_x
end;
